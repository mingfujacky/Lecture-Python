# %%
import pandas as pd
a = ['E', 'W', 'S', 'N']
m = [4522, 3101, 5211, 4613]
s = pd.Series(m, index=a)
s
# Out:
# E    4522
# W    3101
# S    5211
# N    4613
# dtype: int64

# %%
s.plot()
# Out:
# <Axes: >

# %%
import pandas as pd
from pathlib import Path
data_path = Path.cwd().parent / 'files' / 'csv' / '2024_新竹縣_觀光遊憩據點按遊憩據點統計.csv'
df = pd.read_csv(data_path)
df
# df.drop([df.index[1], df.index[13]], inplace=True)

# df['year'] = df['年度'].str[-5:-1]  # Gets characters from position -5 to -1

# # Move 'year' column to first position
# cols = ['year'] + [col for col in df.columns if col != 'year']
# df = df[cols]

# # Drop the '年度' column
# df.drop('年度', axis=1, inplace=True)

# df
# Out:
#            年度     月份                              獅頭山風景區(新竹地區)  \
# 0        Year  Month  Lion’s Head Mountain Scenic Area-Hsinchu
# 1   113(2024)      1                                    107696
# 2   113(2024)      2                                    161325
# 3   113(2024)      3                                    169717
# 4   113(2024)      4                                    118853
# 5   113(2024)      5                                     99738
# 6   113(2024)      6                                     93845
# 7   113(2024)      7                                     91415
# 8   113(2024)      8                                     82241
# 9   113(2024)      9                                     94351
# 10  113(2024)     10                                     96581
# 11  113(2024)     11                                     97269
# 12  113(2024)     12                                     94462
# 13  總計(Total)    NaN                                   1307493
#
# ...
